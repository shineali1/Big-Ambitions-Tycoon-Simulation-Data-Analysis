# %%
import pandas as pd
import glob
import matplotlib as mp
import numpy as np

directory = 'F:/Career/Thesis Projects/Karakata Holdings/Data Files/'
directory2 = 'Individual Business Transactions'

T = pd.read_csv(directory+'UpdatedLedger.csv')
b_list = pd.read_csv(directory+'Unique_Business_ID.csv')
all_store_details = pd.read_csv(directory+'all_store_details.csv')
detailed_product_sales = pd.read_csv(directory+'detailed_product_sales.csv')
purchase_order_details =  pd.read_csv(directory+'purchase_order_details.csv')
weekly_store_sales = pd.read_csv(directory+'weekly_store_sales.csv')

# %%
T
# Out:
#                                          Account  Day        Details  \
# 0                          42 3rd Street Deposit    1        Deposit
# 1                  Purchase from Discount Market    1   ItemPurchase
# 2      Purchase from Mr. Scott's Office Supplies    1   ItemPurchase
# 3      Purchase from Mr. Scott's Office Supplies    1   ItemPurchase
# 4                  Public parking for UMC Desert    1  PublicParking
# ...                                          ...  ...            ...
# 44310                         59 3rd Street Rent  548           Rent
# 44311                         14 2nd Avenue Rent  548           Rent
# 44312                         31 1st Avenue Rent  548           Rent
# 44313                         30 2nd Avenue Rent  548           Rent
# 44314                          9 1st Street Rent  548           Rent
#
#            Amount     Balance  Transaction ID Business Name
# 0     -1230.69200    98769.30             NaN           NaN
# 1       -80.00000    82305.47             NaN           NaN
# 2     -1600.00000    82385.47             NaN           NaN
# 3     -3600.00000    83985.47             NaN           NaN
# 4       -15.00000    82290.47             NaN           NaN
# ...           ...         ...             ...           ...
# 44310   -75.99196  1796673.00             NaN           NaN
# 44311  -731.09990  1784820.00             NaN           NaN
# 44312  -201.10600  1708751.00             NaN           NaN
# 44313 -1158.50600  1940924.00             NaN           NaN
# 44314   -70.98742  1784749.00             NaN           NaN
#
# [44315 rows x 7 columns]

# %%
b_list_active =  b_list[b_list['Status'] == 'Active']
b_list_active
# Out:
#     Transaction ID             Business  Status  Last Operational Day
# 8               13        Katar Midtown  Active                   547
# 9               11   Katalytica Midtown  Active                   547
# 10               9         Karvin Kween  Active                   547
# 11              17      The Green Salad  Active                   547
# 12               5  Karakata Associates  Active                   547
# 13               4       Kalico Midtown  Active                   547
# 14               3         Elite Jewels  Active                   547
# 15               2        Elite Couture  Active                   547
# 16              10        Katalytica HK  Active                   547
# 17              18   The Suits Law Firm  Active                   547

# %%
all_store_details
# Out:
#                              Products  Market Price  Store Price  \
# 0                   Hourly Lawyer Fee           225         1200
# 1               Hourly Programmer Fee           115          300
# 2                  Hourly  Lawyer Fee           225          285
# 3                          Fresh Food             8           20
# 4                            Soda Can             3            6
# 5                         Frozen Food             6           15
# 6        Modern Cheap Female Clothing            60           60
# 7          Modern Cheap Male Clothing            60           60
# 8   Classic Expensive Female Clothing           127          240
# 9    Modern Expensive Female Clothing           132          250
# 10    Classic Expensive Male Clothing           127          240
# 11     Modern Expensive Male Clothing           132          250
# 12                       French Fries             2            4
# 13                              Salad            12           24
# 14                           Soda Can             3            5
# 15                              Pizza            20           40
# 16                      Cheap Jewelry           160          400
# 17                  Expensive Jewelry          1270         2500
# 18              Hourly Programmer Fee           115          800
# 19                     Bottle of Wine            21           45
# 20                              Cigar            12           24
#
#           Address  Store Capacity  Traffic Index  Marketing Cost  \
# 0   31 1st Avenue              10             37            2750
# 1    9 1st Street              10             13            2750
# 2   29 5th Avenue               4             47             500
# 3   29 1st Avenue              40             44            2750
# 4   29 1st Avenue              40             44            2750
# 5   29 1st Avenue              40             44            2750
# 6    3 2nd Avenue              30             53            1350
# 7    3 2nd Avenue              30             53            1350
# 8    5 8th Street              30             10            1350
# 9    5 8th Street              30             10            1350
# 10   5 8th Street              30             10            1350
# 11   5 8th Street              30             10            1350
# 12  19 1st Avenue              30             44            1350
# 13  19 1st Avenue              30             44            1350
# 14  19 1st Avenue              30             44            1350
# 15  19 1st Avenue              30             44            1350
# 16  30 2nd Avenue              75             47            9350
# 17  30 2nd Avenue              75             47            9350
# 18  44 1st Avenue              50             47            6350
# 19   6 3rd Avenue              75             47            9350
# 20   6 3rd Avenue              75             47            9350
#
#           Business Name   Neighbourhood
# 0    The Suits Law Firm         Midtown
# 1         Katalytica HK  Hell's Kitchen
# 2   Karakata Associates     Murray Hill
# 3        Kalico Midtown         Midtown
# 4        Kalico Midtown         Midtown
# 5        Kalico Midtown         Midtown
# 6          Karvin Kween  Hell's Kitchen
# 7          Karvin Kween  Hell's Kitchen
# 8         Elite Couture         Midtown
# 9         Elite Couture         Midtown
# 10        Elite Couture         Midtown
# 11        Elite Couture         Midtown
# 12      The Green Salad         Midtown
# 13      The Green Salad         Midtown
# 14      The Green Salad         Midtown
# 15      The Green Salad         Midtown
# 16         Elite Jewels         Midtown
# 17         Elite Jewels         Midtown
# 18   Katalytica Midtown         Midtown
# 19        Katar Midtown         Midtown
# 20        Katar Midtown         Midtown

# %%
weekly_store_sales = weekly_store_sales.dropna()
weekly_store_sales
# Out:
#     Week  The Suits Law Firm  Katalytica HK  Karakata Associates  \
# 0      1               439.0          440.0                188.0
# 1      2               431.0          437.0                190.0
# 2      3               439.0          440.0                191.0
# 3      4               436.0          439.0                191.0
# 4      5               440.0          440.0                190.0
# 5      6               439.0          434.0                159.0
# 6      7               439.0          439.0                191.0
# 7      8               430.0          437.0                192.0
# 8      9               431.0          440.0                190.0
# 9     10               424.0          438.0                188.0
# 10    11               439.0          438.0                189.0
# 11    12               439.0          435.0                192.0
# 12    13               440.0          430.0                192.0
# 13    14               438.0          438.0                190.0
# 14    15               437.0          414.0                189.0
# 15    16               438.0          435.0                191.0
# 16    17               438.0          423.0                191.0
# 17    18               435.0          426.0                191.0
# 18    19               437.0          433.0                190.0
# 19    20               439.0          303.0                161.0
# 20    21               438.0          279.0                189.0
# 21    22               437.0          280.0                189.0
# 22    23               438.0          279.0                191.0
# 23    24               439.0          280.0                189.0
# 24    25               414.0          280.0                190.0
# 25    26               405.0          280.0                190.0
#
#     Kalico Midtown  Karvin Kween  Elite Couture  The Green Salad  \
# 0          16683.0        1596.0         3005.0          11452.0
# 1          16880.0        1561.0         3289.0          11447.0
# 2          16891.0        1727.0         3186.0          11547.0
# 3          17597.0        1845.0         2962.0          11375.0
# 4          17614.0        2060.0         3120.0          11337.0
# 5          16778.0        1968.0         3191.0          11330.0
# 6          16706.0        1833.0         3034.0          11457.0
# 7          16887.0        1757.0         2801.0          11805.0
# 8          16777.0        2215.0         2869.0          11526.0
# 9          17503.0        1704.0         3122.0          11358.0
# 10         17745.0        1652.0         3076.0          11172.0
# 11         16957.0        1717.0         3161.0          11207.0
# 12         17727.0        1589.0         3234.0          11869.0
# 13         16952.0        1722.0         3104.0           9723.0
# 14         16796.0        1707.0         3110.0          11310.0
# 15         16980.0        2036.0         3047.0          11350.0
# 16         17153.0        1829.0         2779.0          11549.0
# 17         13596.0        1722.0         2938.0          12368.0
# 18         17117.0        1722.0         2958.0          11650.0
# 19         16578.0        2167.0         2912.0          11525.0
# 20         16615.0        2225.0         2985.0          11592.0
# 21         16847.0        2240.0         2687.0          11502.0
# 22         17525.0        2388.0         3142.0          12010.0
# 23         17139.0        2231.0         2983.0          11302.0
# 24         17386.0        1697.0         2974.0          11052.0
# 25         16345.0        2171.0         3009.0          11069.0
#
#     Elite Jewels  Katalytica Midtown  Katar Midtown
# 0         3875.0              1646.0        18911.0
# 1         3933.0              1649.0        19085.0
# 2         3697.0              1664.0        19709.0
# 3         3871.0              1660.0        20025.0
# 4         3865.0              1675.0        18054.0
# 5         4045.0              1670.0        19109.0
# 6         4166.0              1657.0        18835.0
# 7         3982.0              1669.0        18948.0
# 8         3892.0              1672.0        13631.0
# 9         4062.0              1672.0        18482.0
# 10        4242.0              1660.0        18915.0
# 11        4067.0              1661.0        18878.0
# 12        3886.0              1648.0        13946.0
# 13        3876.0              1661.0        18759.0
# 14        3919.0              1640.0        18949.0
# 15        3946.0              1681.0        18900.0
# 16        4195.0              1655.0        13676.0
# 17        4142.0              1672.0        19337.0
# 18        3869.0              1669.0        19177.0
# 19        3866.0              1666.0        18978.0
# 20        3869.0              1665.0        19647.0
# 21        3847.0              1660.0        20451.0
# 22        3845.0              1667.0        20468.0
# 23        3955.0              1674.0        15960.0
# 24        4207.0              1661.0        19724.0
# 25        4082.0              1653.0        18911.0

# %%
purchase_order_details
# Out:
#                               Product  Repeats Every n Day  Units  \
# 0        Modern Cheap Female Clothing                    7   1000
# 1          Modern Cheap Male Clothing                    7   1000
# 2   Classic Expensive Female Clothing                    7   1000
# 3     Classic Expensive Male Clothing                    7   1000
# 4    Modern Expensive Female Clothing                    7   1000
# 5      Modern Expensive Male Clothing                    7   1000
# 6                      Bottle of Wine                    3   5000
# 7                               Cigar                    3  10800
# 8                       Cheap Jewelry                    3   2000
# 9                   Expensive Jewelry                    3    250
# 10                              Pizza                    7   1890
# 11                       French Fries                    7   5600
# 12                         Fresh Food                    7   8000
# 13                        Frozen Food                    7   8000
# 14                              Salad                    7   7350
# 15                           Soda Can                    7   4000
# 16                           Soda Can                    7   6000
# 17                           Paperbag                    7  35000
# 18                           Paperbag                    7  35000
#
#     Cost Per Unit Purchasing Agent           Import Agency  Warehouse
# 0            7.21    Merit Johnson       Bluestone Imports          1
# 1            7.14    Merit Johnson       Bluestone Imports          1
# 2           12.64    Merit Johnson       Bluestone Imports          1
# 3           12.21    Merit Johnson       Bluestone Imports          1
# 4            9.37    Merit Johnson       Bluestone Imports          1
# 5           11.12    Merit Johnson       Bluestone Imports          1
# 6            3.36   Mollie Jenkins     United Ocean Import          1
# 7            2.21   Mollie Jenkins     United Ocean Import          1
# 8           61.57   Mollie Jenkins     United Ocean Import          2
# 9          556.43   Mollie Jenkins     United Ocean Import          1
# 10           4.81    Kathryn James  Seaside Internationals          1
# 11           0.41    Kathryn James  Seaside Internationals          1
# 12           1.65    Kathryn James  Seaside Internationals          2
# 13           0.80    Kathryn James  Seaside Internationals          2
# 14           1.90    Kathryn James  Seaside Internationals          1
# 15           0.17    Kathryn James  Seaside Internationals          2
# 16           0.21     Zoe Campbell        JetCargo Imports          2
# 17           0.08     Zoe Campbell        JetCargo Imports          2
# 18           0.10   Theodore Brown        JetCargo Imports          1

# %%
#let us understand more about Kalico Midtown, an upscale supermarket set up in the wealthy neighbourhood of Midtown
kalico_midtown_ledger = pd.read_csv(directory+directory2+'/Kalico Midtown.csv')
kalico_midtown_ledger
# Out:
#                                             Account  Day    Details  Amount  \
# 0       Mollie Martinez (Kalico Midtown Daily Wage)  204       Wage  -125.0
# 1           Leon Powell (Kalico Midtown Daily Wage)  204       Wage  -160.0
# 2       Mollie Martinez (Kalico Midtown Daily Wage)  205       Wage  -200.0
# 3          Eve Sullivan (Kalico Midtown Daily Wage)  205       Wage  -240.0
# 4     Wilhelmina Cooper (Kalico Midtown Daily Wage)  205       Wage  -330.0
# ...                                             ...  ...        ...     ...
# 2004        Joel Rogers (Kalico Midtown Daily Wage)  547       Wage   -90.0
# 2005  Wilhelmina Cooper (Kalico Midtown Daily Wage)  547       Wage  -264.0
# 2006        Leon Powell (Kalico Midtown Daily Wage)  547       Wage  -256.0
# 2007    Mollie Martinez (Kalico Midtown Daily Wage)  547       Wage  -200.0
# 2008         Marketing campaigns for Kalico Midtown  548  Marketing -2750.0
#
#       Transaction ID   Business Name
# 0                4.0  Kalico Midtown
# 1                4.0  Kalico Midtown
# 2                4.0  Kalico Midtown
# 3                4.0  Kalico Midtown
# 4                4.0  Kalico Midtown
# ...              ...             ...
# 2004             4.0  Kalico Midtown
# 2005             4.0  Kalico Midtown
# 2006             4.0  Kalico Midtown
# 2007             4.0  Kalico Midtown
# 2008             4.0  Kalico Midtown
#
# [2009 rows x 6 columns]

# %%
#Days of Data Available:
days = kalico_midtown_ledger.iloc[-1]['Day']-kalico_midtown_ledger.iloc[0]['Day']
days
# Out:
# 344

# %%
#business_names = all_store_details['Business Name'].unique()
kalico_midtown_details = all_store_details[all_store_details['Business Name'] == 'Kalico Midtown']
kalico_midtown_details
#business_names
# Out:
#       Products  Market Price  Store Price        Address  Store Capacity  \
# 3   Fresh Food             8           20  29 1st Avenue              40
# 4     Soda Can             3            6  29 1st Avenue              40
# 5  Frozen Food             6           15  29 1st Avenue              40
#
#    Traffic Index  Marketing Cost   Business Name Neighbourhood
# 3             44            2750  Kalico Midtown       Midtown
# 4             44            2750  Kalico Midtown       Midtown
# 5             44            2750  Kalico Midtown       Midtown

# %%
detailed_product_sales
# Out:
#     Week  Hourly Lawyer Fee  Hourly Programmer Fee  Hourly  Lawyer Fee  \
# 0      1                439                    440                 188
# 1      2                431                    437                 190
# 2      3                439                    440                 191
# 3      4                436                    439                 191
# 4      5                440                    440                 190
# 5      6                439                    434                 159
# 6      7                439                    439                 191
# 7      8                430                    437                 192
# 8      9                431                    440                 190
# 9     10                424                    438                 188
# 10    11                439                    438                 189
# 11    12                439                    435                 192
# 12    13                440                    430                 192
# 13    14                438                    438                 190
# 14    15                437                    414                 189
# 15    16                438                    435                 191
# 16    17                438                    423                 191
# 17    18                435                    426                 191
#
#     Fresh Food  Soda Can  Frozen Food  Modern Cheap Female Clothing  \
# 0         5972      2589         4040                           453
# 1         5953      2804         4041                           487
# 2         5953      2847         4009                           526
# 3         6466      2774         4275                           647
# 4         6472      2746         4314                           774
# 5         5953      2696         4047                           702
# 6         5990      2599         4035                           632
# 7         5932      2854         4019                           551
# 8         5947      2707         4041                           760
# 9         6465      2868         4088                           506
# 10        6470      2884         4309                           481
# 11        5913      2720         4242                           511
# 12        5900      3724         4021                           443
# 13        5956      2864         4050                           516
# 14        6007      2665         4042                           506
# 15        6380      2503         4015                           761
# 16        6468      2501         4102                           657
# 17        6061      3213         4322                           516
#
#     Modern Cheap Male Clothing  Classic Expensive Female Clothing  ...  \
# 0                          448                                422  ...
# 1                          379                                506  ...
# 2                          506                                453  ...
# 3                          503                                380  ...
# 4                          591                                404  ...
# 5                          571                                437  ...
# 6                          506                                412  ...
# 7                          511                                346  ...
# 8                          760                                350  ...
# 9                          503                                379  ...
# 10                         476                                376  ...
# 11                         511                                379  ...
# 12                         451                                378  ...
# 13                         511                                378  ...
# 14                         506                                380  ...
# 15                         580                                378  ...
# 16                         477                                349  ...
# 17                         511                                370  ...
#
#     Modern Expensive Male Clothing  French Fries  Salad  Soda Can.1  Pizza  \
# 0                              761          4168   1917        1360   1251
# 1                              768          4187   1834        1420   1250
# 2                              763          4158   1717        1680   1236
# 3                              770          4145   1784        1440   1250
# 4                              848          4175   1921        1240   1245
# 5                              872          4160   1862        1300   1252
# 6                              792          4314   1724        1420   1243
# 7                              702          4332   1786        1680   1251
# 8                              735          4157   1923        1440   1250
# 9                              920          4187   1923        1240   1252
# 10                             894          4136   1914        1120   1246
# 11                             883          4214   1786        1200   1251
# 12                             923          4169   1721        1980   1243
# 13                             803          3540   1467         900   1060
# 14                             769          4194   1731        1380   1249
# 15                             768          4143   1711        1500   1240
# 16                             729          4179   1789        1440   1385
# 17                             827          4155   1919        2100   1438
#
#     Cheap Jewelry  Expensive Jewelry  Hourly Programmer Fee.1  Bottle of Wine  \
# 0            2046                385                     1646            5465
# 1            2029                460                     1649            5754
# 2            1839                414                     1664            6125
# 3            2047                380                     1660            5732
# 4            2045                376                     1675            4829
# 5            2217                384                     1670            5456
# 6            2345                377                     1657            5457
# 7            2153                385                     1669            5485
# 8            2035                413                     1672            3333
# 9            2128                490                     1672            5301
# 10           2329                469                     1660            5474
# 11           2247                376                     1661            5466
# 12           2050                392                     1648            3460
# 13           2044                388                     1661            5419
# 14           2044                431                     1640            5488
# 15           2041                461                     1681            5468
# 16           2339                412                     1655            3360
# 17           2326                372                     1672            5981
#
#     Cigar
# 0    8072
# 1    7957
# 2    8210
# 3    8919
# 4    7851
# 5    8279
# 6    8004
# 7    8089
# 8    4924
# 9    7807
# 10   8067
# 11   8038
# 12   5112
# 13   7966
# 14   8087
# 15   8058
# 16   4942
# 17   7982
#
# [18 rows x 22 columns]

# %%
#Week 2 is day 373-379
kalico_week_2 = kalico_midtown_ledger[(kalico_midtown_ledger['Day']>=373)&(kalico_midtown_ledger['Day']<=379)
                                      &(kalico_midtown_ledger['Details']=='Revenue')]
kalico_week_2
# Out:
#                     Account  Day  Details   Amount  Transaction ID  \
# 948  Kalico Midtown Revenue  373  Revenue  28385.0             4.0
# 954  Kalico Midtown Revenue  374  Revenue  27626.0             4.0
# 955  Kalico Midtown Revenue  375  Revenue  28322.0             4.0
# 961  Kalico Midtown Revenue  376  Revenue  29155.0             4.0
# 967  Kalico Midtown Revenue  377  Revenue  29144.0             4.0
# 974  Kalico Midtown Revenue  378  Revenue  25001.0             4.0
# 981  Kalico Midtown Revenue  379  Revenue  28866.0             4.0
#
#       Business Name
# 948  Kalico Midtown
# 954  Kalico Midtown
# 955  Kalico Midtown
# 961  Kalico Midtown
# 967  Kalico Midtown
# 974  Kalico Midtown
# 981  Kalico Midtown

# %%
from sympy import symbols, solve

kalico_week_2_revenue = kalico_week_2['Amount'].sum()
print(f'{kalico_week_2_revenue:,.2f}')
# Out:
# 196,499.00

# %%
theoretical_revenue = (kalico_midtown_details[kalico_midtown_details['Products']=='Fresh Food']['Store Price'].values[0]*
                      detailed_product_sales[detailed_product_sales['Week']==2]['Fresh Food'].values[0]) + (kalico_midtown_details[kalico_midtown_details['Products']=='Soda Can']['Store Price'].values[0]*
                      detailed_product_sales[detailed_product_sales['Week']==2]['Soda Can'].values[0]) + (kalico_midtown_details[kalico_midtown_details['Products']=='Frozen Food']['Store Price'].values[0]*
                      detailed_product_sales[detailed_product_sales['Week']==2]['Frozen Food'].values[0])
print(f'{theoretical_revenue:,}')
# Out:
# 196,499

# %%
#Theoretical Revenue and Recorded Revenue are the same

# %%
kalico_midtown_ledger['Details'].unique()
# Out:
# array(['Wage', 'Revenue', 'Marketing', 'ReplacementWage'], dtype=object)

# %%
kalico_net_sales = weekly_store_sales['Kalico Midtown'].sum() - weekly_store_sales.iloc[0]['Kalico Midtown']
kalico_net_sales
# Out:
# 423091.0

# %%
kalico_net_revenue = kalico_midtown_ledger[(kalico_midtown_ledger['Day']>=373)&(kalico_midtown_ledger['Details']=='Revenue')]['Amount'].sum()
kalico_net_revenue
# Out:
# 5015331.0

# %%
average_price_per_item = round((kalico_net_revenue/kalico_net_sales),2)
average_price_per_item
# Out:
# 11.85

# %%
import math
kalico_sales_data = kalico_midtown_ledger[(kalico_midtown_ledger['Details']=='Revenue')]
kalico_sales_data['Sales'] = (kalico_sales_data['Amount']/average_price_per_item).apply(math.ceil)
kalico_sales_data
# Out:
# C:\Users\shine\AppData\Local\Temp\ipykernel_20352\4082572211.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kalico_sales_data['Sales'] = (kalico_sales_data['Amount']/average_price_per_item).apply(math.ceil)
#                      Account  Day  Details   Amount  Transaction ID  \
# 6     Kalico Midtown Revenue  205  Revenue  10423.0             4.0
# 11    Kalico Midtown Revenue  206  Revenue  11188.0             4.0
# 16    Kalico Midtown Revenue  207  Revenue  15265.0             4.0
# 23    Kalico Midtown Revenue  208  Revenue  23629.0             4.0
# 30    Kalico Midtown Revenue  209  Revenue  15425.0             4.0
# ...                      ...  ...      ...      ...             ...
# 1983  Kalico Midtown Revenue  543  Revenue  30792.0             4.0
# 1984  Kalico Midtown Revenue  544  Revenue  15772.0             4.0
# 1988  Kalico Midtown Revenue  545  Revenue  31241.0             4.0
# 1995  Kalico Midtown Revenue  546  Revenue  24520.0             4.0
# 2001  Kalico Midtown Revenue  547  Revenue  30818.0             4.0
#
#        Business Name  Sales
# 6     Kalico Midtown    880
# 11    Kalico Midtown    945
# 16    Kalico Midtown   1289
# 23    Kalico Midtown   1995
# 30    Kalico Midtown   1302
# ...              ...    ...
# 1983  Kalico Midtown   2599
# 1984  Kalico Midtown   1331
# 1988  Kalico Midtown   2637
# 1995  Kalico Midtown   2070
# 2001  Kalico Midtown   2601
#
# [323 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
plt.figure()
#kalico_sales_data.plot(x="Day",y="Sales",kind="kde")
kalico_sales_data.plot(x="Day",y="Sales")
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
T
# Out:
#                                          Account  Day        Details  \
# 0                          42 3rd Street Deposit    1        Deposit
# 1                  Purchase from Discount Market    1   ItemPurchase
# 2      Purchase from Mr. Scott's Office Supplies    1   ItemPurchase
# 3      Purchase from Mr. Scott's Office Supplies    1   ItemPurchase
# 4                  Public parking for UMC Desert    1  PublicParking
# ...                                          ...  ...            ...
# 44310                         59 3rd Street Rent  548           Rent
# 44311                         14 2nd Avenue Rent  548           Rent
# 44312                         31 1st Avenue Rent  548           Rent
# 44313                         30 2nd Avenue Rent  548           Rent
# 44314                          9 1st Street Rent  548           Rent
#
#            Amount     Balance  Transaction ID Business Name
# 0     -1230.69200    98769.30             NaN           NaN
# 1       -80.00000    82305.47             NaN           NaN
# 2     -1600.00000    82385.47             NaN           NaN
# 3     -3600.00000    83985.47             NaN           NaN
# 4       -15.00000    82290.47             NaN           NaN
# ...           ...         ...             ...           ...
# 44310   -75.99196  1796673.00             NaN           NaN
# 44311  -731.09990  1784820.00             NaN           NaN
# 44312  -201.10600  1708751.00             NaN           NaN
# 44313 -1158.50600  1940924.00             NaN           NaN
# 44314   -70.98742  1784749.00             NaN           NaN
#
# [44315 rows x 7 columns]

# %%
'''
Day 548 is a Tuesday.
Doing a few calculations, we find that Day 1 is a Monday. Therefore, we can write a function that would return the 
day of the week based on what remainder that day returns when divided by 7, for example, if day%7=1, it's a Monday, 
if it's 2, then it's a tuesday, so on and so forth.
'''
def day_week(day):
    rem = day % 7
    days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

    if rem == 1:
        return days[0]
    elif rem == 2:
        return days[1]
    elif rem == 3:
        return days[2]
    elif rem == 4:
        return days[3]
    elif rem == 5:
        return days[4]
    elif rem == 6:
        return days[5]
    elif rem == 0:
        return days[6]

day_week(548)
# Out:
# 'Tue'

# %%
kalico_sales_data['Day of Week'] = kalico_sales_data['Day'].apply(lambda x:day_week(x))
kalico_sales_data
# Out:
# C:\Users\shine\AppData\Local\Temp\ipykernel_20352\1270406126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kalico_sales_data['Day of Week'] = kalico_sales_data['Day'].apply(lambda x:day_week(x))
#                      Account  Day  Details   Amount  Transaction ID  \
# 6     Kalico Midtown Revenue  205  Revenue  10423.0             4.0
# 11    Kalico Midtown Revenue  206  Revenue  11188.0             4.0
# 16    Kalico Midtown Revenue  207  Revenue  15265.0             4.0
# 23    Kalico Midtown Revenue  208  Revenue  23629.0             4.0
# 30    Kalico Midtown Revenue  209  Revenue  15425.0             4.0
# ...                      ...  ...      ...      ...             ...
# 1983  Kalico Midtown Revenue  543  Revenue  30792.0             4.0
# 1984  Kalico Midtown Revenue  544  Revenue  15772.0             4.0
# 1988  Kalico Midtown Revenue  545  Revenue  31241.0             4.0
# 1995  Kalico Midtown Revenue  546  Revenue  24520.0             4.0
# 2001  Kalico Midtown Revenue  547  Revenue  30818.0             4.0
#
#        Business Name  Sales Day of Week
# 6     Kalico Midtown    880         Tue
# 11    Kalico Midtown    945         Wed
# 16    Kalico Midtown   1289         Thu
# 23    Kalico Midtown   1995         Fri
# 30    Kalico Midtown   1302         Sat
# ...              ...    ...         ...
# 1983  Kalico Midtown   2599         Thu
# 1984  Kalico Midtown   1331         Fri
# 1988  Kalico Midtown   2637         Sat
# 1995  Kalico Midtown   2070         Sun
# 2001  Kalico Midtown   2601         Mon
#
# [323 rows x 8 columns]

# %%
day_dump = kalico_sales_data['Day'].unique()
day_dump
# Out:
# array([205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217,
#        218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230,
#        231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243,
#        244, 245, 246, 247, 256, 257, 258, 259, 260, 261, 262, 263, 264,
#        265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277,
#        278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290,
#        291, 292, 293, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307,
#        308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320,
#        321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333,
#        334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346,
#        347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359,
#        360, 361, 362, 363, 364, 373, 374, 375, 376, 377, 378, 379, 380,
#        381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393,
#        394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406,
#        407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419,
#        420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432,
#        433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445,
#        446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458,
#        459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471,
#        472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484,
#        485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497,
#        498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510,
#        511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523,
#        524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536,
#        537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547], dtype=int64)

# %%
day_dump[10]
# Out:
# 215

# %%
#We write a function day_break to find out if there are any breaks in our data, 
#ie. have we missed data from any period between day 205 and 547
def day_break(day_dump):
    for i in range(len(day_dump)-2):
        break_points = []
        if (day_dump[i+1]-day_dump[i] !=1):
            break_points.append(day_dump[i])
        else:
            continue
        
        return break_points
            

day_break(day_dump)
# Out:
# [247]

# %%
#We see that there is a break at day 247.
#The following cell block assigns marketing cost per day to a new column 'Marketing' in the kalico_sales_data dataframe
kalico_marketing_data = kalico_midtown_ledger[kalico_midtown_ledger['Details']=='Marketing']
kalico_marketing_data.rename({'Amount':'Marketing'},axis=1,inplace=True)
'''
def assign_mark(kalico_midtown_ledger):
    kalico_marketing_array = []
    for i in range(len(kalico_sales_data)):
        if (kalico_sales_data.iloc[i]['Day'] == kalico_midtown_ledger[kalico_midtown_ledger['Details']=='Marketing'].iloc[i]['Day']):
            kalico_marketing_array.append(kalico_midtown_ledger[kalico_midtown_ledger['Details']=='Marketing'].iloc[i]['Amount'])
        else:
            kalico_marketing_array.append(0)
    return kalico_marketing_array
'''

#kalico_sales_data['Marketing'] = assign_mark(kalico_midtown_ledger)
kalico_sales_data = pd.merge(kalico_sales_data,kalico_marketing_data[['Day','Marketing']], on='Day',how='left')
kalico_sales_data
# Out:
# C:\Users\shine\AppData\Local\Temp\ipykernel_20352\3771180038.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kalico_marketing_data.rename({'Amount':'Marketing'},axis=1,inplace=True)
#                     Account  Day  Details   Amount  Transaction ID  \
# 0    Kalico Midtown Revenue  205  Revenue  10423.0             4.0
# 1    Kalico Midtown Revenue  206  Revenue  11188.0             4.0
# 2    Kalico Midtown Revenue  207  Revenue  15265.0             4.0
# 3    Kalico Midtown Revenue  207  Revenue  15265.0             4.0
# 4    Kalico Midtown Revenue  208  Revenue  23629.0             4.0
# ..                      ...  ...      ...      ...             ...
# 319  Kalico Midtown Revenue  543  Revenue  30792.0             4.0
# 320  Kalico Midtown Revenue  544  Revenue  15772.0             4.0
# 321  Kalico Midtown Revenue  545  Revenue  31241.0             4.0
# 322  Kalico Midtown Revenue  546  Revenue  24520.0             4.0
# 323  Kalico Midtown Revenue  547  Revenue  30818.0             4.0
#
#       Business Name  Sales Day of Week  Marketing
# 0    Kalico Midtown    880         Tue        NaN
# 1    Kalico Midtown    945         Wed        NaN
# 2    Kalico Midtown   1289         Thu    -2500.0
# 3    Kalico Midtown   1289         Thu     -250.0
# 4    Kalico Midtown   1995         Fri    -2750.0
# ..              ...    ...         ...        ...
# 319  Kalico Midtown   2599         Thu    -2750.0
# 320  Kalico Midtown   1331         Fri    -2750.0
# 321  Kalico Midtown   2637         Sat    -2750.0
# 322  Kalico Midtown   2070         Sun    -2750.0
# 323  Kalico Midtown   2601         Mon    -2750.0
#
# [324 rows x 9 columns]

# %%
kalico_midtown_ledger['Details'].unique()
# Out:
# array(['Wage', 'Revenue', 'Marketing', 'ReplacementWage'], dtype=object)

# %%
#Obtain the Daily Wage Data from the Ledger
kalico_wages = kalico_midtown_ledger[kalico_midtown_ledger['Details']=='Wage']
net_wages = kalico_wages.groupby('Day')['Amount'].sum()
net_wages = net_wages.reset_index().rename(columns={'Amount': 'Net Wages'})
net_wages
# Out:
#      Day  Net Wages
# 0    204     -285.0
# 1    205    -1026.0
# 2    206     -954.0
# 3    207     -964.0
# 4    208    -1024.0
# ..   ...        ...
# 308  543     -964.0
# 309  544     -520.0
# 310  545     -968.0
# 311  546     -622.0
# 312  547    -1050.0
#
# [313 rows x 2 columns]

# %%
#Merge this data into kalico_sales_data
kalico_sales_data = pd.merge(kalico_sales_data,net_wages[['Day','Net Wages']], on='Day',how='left')
kalico_sales_data
# Out:
#                     Account  Day  Details   Amount  Transaction ID  \
# 0    Kalico Midtown Revenue  205  Revenue  10423.0             4.0
# 1    Kalico Midtown Revenue  206  Revenue  11188.0             4.0
# 2    Kalico Midtown Revenue  207  Revenue  15265.0             4.0
# 3    Kalico Midtown Revenue  207  Revenue  15265.0             4.0
# 4    Kalico Midtown Revenue  208  Revenue  23629.0             4.0
# ..                      ...  ...      ...      ...             ...
# 319  Kalico Midtown Revenue  543  Revenue  30792.0             4.0
# 320  Kalico Midtown Revenue  544  Revenue  15772.0             4.0
# 321  Kalico Midtown Revenue  545  Revenue  31241.0             4.0
# 322  Kalico Midtown Revenue  546  Revenue  24520.0             4.0
# 323  Kalico Midtown Revenue  547  Revenue  30818.0             4.0
#
#       Business Name  Sales Day of Week  Marketing  Net Wages
# 0    Kalico Midtown    880         Tue        NaN    -1026.0
# 1    Kalico Midtown    945         Wed        NaN     -954.0
# 2    Kalico Midtown   1289         Thu    -2500.0     -964.0
# 3    Kalico Midtown   1289         Thu     -250.0     -964.0
# 4    Kalico Midtown   1995         Fri    -2750.0    -1024.0
# ..              ...    ...         ...        ...        ...
# 319  Kalico Midtown   2599         Thu    -2750.0     -964.0
# 320  Kalico Midtown   1331         Fri    -2750.0     -520.0
# 321  Kalico Midtown   2637         Sat    -2750.0     -968.0
# 322  Kalico Midtown   2070         Sun    -2750.0     -622.0
# 323  Kalico Midtown   2601         Mon    -2750.0    -1050.0
#
# [324 rows x 10 columns]

# %%
replacement_wages = kalico_midtown_ledger[kalico_midtown_ledger['Details']=='ReplacementWage']
replacement_wages
# Out:
#                                                Account  Day          Details  \
# 283  Replacement for Mollie Martinez (Kalico Midtow...  257  ReplacementWage
#
#      Amount  Transaction ID   Business Name
# 283  -250.0             4.0  Kalico Midtown

# %%
# We see that replacement wage has been paid only for a single day. 
# This means, omitting it from the sales model might not affect the performance much.

# %%
kalico_sales_data = kalico_sales_data.drop('Details',axis=1)

# %%
kalico_sales_data
# Out:
#                     Account  Day   Amount  Transaction ID   Business Name  \
# 0    Kalico Midtown Revenue  205  10423.0             4.0  Kalico Midtown
# 1    Kalico Midtown Revenue  206  11188.0             4.0  Kalico Midtown
# 2    Kalico Midtown Revenue  207  15265.0             4.0  Kalico Midtown
# 3    Kalico Midtown Revenue  207  15265.0             4.0  Kalico Midtown
# 4    Kalico Midtown Revenue  208  23629.0             4.0  Kalico Midtown
# ..                      ...  ...      ...             ...             ...
# 319  Kalico Midtown Revenue  543  30792.0             4.0  Kalico Midtown
# 320  Kalico Midtown Revenue  544  15772.0             4.0  Kalico Midtown
# 321  Kalico Midtown Revenue  545  31241.0             4.0  Kalico Midtown
# 322  Kalico Midtown Revenue  546  24520.0             4.0  Kalico Midtown
# 323  Kalico Midtown Revenue  547  30818.0             4.0  Kalico Midtown
#
#      Sales Day of Week  Marketing  Net Wages
# 0      880         Tue        NaN    -1026.0
# 1      945         Wed        NaN     -954.0
# 2     1289         Thu    -2500.0     -964.0
# 3     1289         Thu     -250.0     -964.0
# 4     1995         Fri    -2750.0    -1024.0
# ..     ...         ...        ...        ...
# 319   2599         Thu    -2750.0     -964.0
# 320   1331         Fri    -2750.0     -520.0
# 321   2637         Sat    -2750.0     -968.0
# 322   2070         Sun    -2750.0     -622.0
# 323   2601         Mon    -2750.0    -1050.0
#
# [324 rows x 9 columns]

# %%
kalico_sales_data.rename({'Amount':'Revenue'},axis=1,inplace=True)
kalico_sales_data
# Out:
#                     Account  Day  Revenue  Transaction ID   Business Name  \
# 0    Kalico Midtown Revenue  205  10423.0             4.0  Kalico Midtown
# 1    Kalico Midtown Revenue  206  11188.0             4.0  Kalico Midtown
# 2    Kalico Midtown Revenue  207  15265.0             4.0  Kalico Midtown
# 3    Kalico Midtown Revenue  207  15265.0             4.0  Kalico Midtown
# 4    Kalico Midtown Revenue  208  23629.0             4.0  Kalico Midtown
# ..                      ...  ...      ...             ...             ...
# 319  Kalico Midtown Revenue  543  30792.0             4.0  Kalico Midtown
# 320  Kalico Midtown Revenue  544  15772.0             4.0  Kalico Midtown
# 321  Kalico Midtown Revenue  545  31241.0             4.0  Kalico Midtown
# 322  Kalico Midtown Revenue  546  24520.0             4.0  Kalico Midtown
# 323  Kalico Midtown Revenue  547  30818.0             4.0  Kalico Midtown
#
#      Sales Day of Week  Marketing  Net Wages
# 0      880         Tue        NaN    -1026.0
# 1      945         Wed        NaN     -954.0
# 2     1289         Thu    -2500.0     -964.0
# 3     1289         Thu     -250.0     -964.0
# 4     1995         Fri    -2750.0    -1024.0
# ..     ...         ...        ...        ...
# 319   2599         Thu    -2750.0     -964.0
# 320   1331         Fri    -2750.0     -520.0
# 321   2637         Sat    -2750.0     -968.0
# 322   2070         Sun    -2750.0     -622.0
# 323   2601         Mon    -2750.0    -1050.0
#
# [324 rows x 9 columns]

# %%
kalico_sales_data = kalico_sales_data.drop(['Transaction ID','Business Name','Account'],axis=1)

# %%
kalico_sales_data
# Out:
#      Day  Revenue  Sales Day of Week  Marketing  Net Wages
# 0    205  10423.0    880         Tue        NaN    -1026.0
# 1    206  11188.0    945         Wed        NaN     -954.0
# 2    207  15265.0   1289         Thu    -2500.0     -964.0
# 3    207  15265.0   1289         Thu     -250.0     -964.0
# 4    208  23629.0   1995         Fri    -2750.0    -1024.0
# ..   ...      ...    ...         ...        ...        ...
# 319  543  30792.0   2599         Thu    -2750.0     -964.0
# 320  544  15772.0   1331         Fri    -2750.0     -520.0
# 321  545  31241.0   2637         Sat    -2750.0     -968.0
# 322  546  24520.0   2070         Sun    -2750.0     -622.0
# 323  547  30818.0   2601         Mon    -2750.0    -1050.0
#
# [324 rows x 6 columns]

# %%
#kalico_sales_data.to_csv(directory+'kalico_sales_final_set.csv',index=False)

# %%
kalico_sales_data = kalico_sales_data.fillna(0)
kalico_sales_data['Income']=kalico_sales_data['Revenue']+kalico_sales_data['Marketing']+kalico_sales_data['Net Wages']
kalico_sales_data
# Out:
#      Day  Revenue  Sales Day of Week  Marketing  Net Wages   Income
# 0    205  10423.0    880         Tue        0.0    -1026.0   9397.0
# 1    206  11188.0    945         Wed        0.0     -954.0  10234.0
# 2    207  15265.0   1289         Thu    -2500.0     -964.0  11801.0
# 3    207  15265.0   1289         Thu     -250.0     -964.0  14051.0
# 4    208  23629.0   1995         Fri    -2750.0    -1024.0  19855.0
# ..   ...      ...    ...         ...        ...        ...      ...
# 319  543  30792.0   2599         Thu    -2750.0     -964.0  27078.0
# 320  544  15772.0   1331         Fri    -2750.0     -520.0  12502.0
# 321  545  31241.0   2637         Sat    -2750.0     -968.0  27523.0
# 322  546  24520.0   2070         Sun    -2750.0     -622.0  21148.0
# 323  547  30818.0   2601         Mon    -2750.0    -1050.0  27018.0
#
# [324 rows x 7 columns]

# %%
kalico_sales_data = kalico_sales_data.drop(['Revenue'],axis=1)
kalico_sales_data
# Out:
#      Day  Sales Day of Week  Marketing  Net Wages   Income
# 0    205    880         Tue        0.0    -1026.0   9397.0
# 1    206    945         Wed        0.0     -954.0  10234.0
# 2    207   1289         Thu    -2500.0     -964.0  11801.0
# 3    207   1289         Thu     -250.0     -964.0  14051.0
# 4    208   1995         Fri    -2750.0    -1024.0  19855.0
# ..   ...    ...         ...        ...        ...      ...
# 319  543   2599         Thu    -2750.0     -964.0  27078.0
# 320  544   1331         Fri    -2750.0     -520.0  12502.0
# 321  545   2637         Sat    -2750.0     -968.0  27523.0
# 322  546   2070         Sun    -2750.0     -622.0  21148.0
# 323  547   2601         Mon    -2750.0    -1050.0  27018.0
#
# [324 rows x 6 columns]

# %%
kalico_sales_data=kalico_sales_data.rename({'Income':'Profit'},axis=1)
kalico_sales_data
# Out:
#      Day  Sales Day of Week  Marketing  Net Wages   Profit
# 0    205    880         Tue        0.0    -1026.0   9397.0
# 1    206    945         Wed        0.0     -954.0  10234.0
# 2    207   1289         Thu    -2500.0     -964.0  11801.0
# 3    207   1289         Thu     -250.0     -964.0  14051.0
# 4    208   1995         Fri    -2750.0    -1024.0  19855.0
# ..   ...    ...         ...        ...        ...      ...
# 319  543   2599         Thu    -2750.0     -964.0  27078.0
# 320  544   1331         Fri    -2750.0     -520.0  12502.0
# 321  545   2637         Sat    -2750.0     -968.0  27523.0
# 322  546   2070         Sun    -2750.0     -622.0  21148.0
# 323  547   2601         Mon    -2750.0    -1050.0  27018.0
#
# [324 rows x 6 columns]

# %%
kalico_sales_data['Day of Week'] = kalico_sales_data['Day'].apply(lambda x:x%7)

# %%
#kalico_sales_data = kalico_sales_data.drop(('Day of Week Number'),axis=1)
kalico_sales_data['Marketing']=abs(kalico_sales_data['Marketing'])
kalico_sales_data['Net Wages']=abs(kalico_sales_data['Net Wages'])
kalico_sales_data ['Net Expenses'] = abs(kalico_sales_data['Marketing']+kalico_sales_data['Net Wages'])
kalico_sales_data
# Out:
#      Day  Sales  Day of Week  Marketing  Net Wages   Profit  Net Expenses
# 0    205    880            2        0.0     1026.0   9397.0        1026.0
# 1    206    945            3        0.0      954.0  10234.0         954.0
# 2    207   1289            4     2500.0      964.0  11801.0        3464.0
# 3    207   1289            4      250.0      964.0  14051.0        1214.0
# 4    208   1995            5     2750.0     1024.0  19855.0        3774.0
# ..   ...    ...          ...        ...        ...      ...           ...
# 319  543   2599            4     2750.0      964.0  27078.0        3714.0
# 320  544   1331            5     2750.0      520.0  12502.0        3270.0
# 321  545   2637            6     2750.0      968.0  27523.0        3718.0
# 322  546   2070            0     2750.0      622.0  21148.0        3372.0
# 323  547   2601            1     2750.0     1050.0  27018.0        3800.0
#
# [324 rows x 7 columns]

# %%
#Data Summary
kalico_sales_data.describe()
# Out:
#               Day        Sales  Day of Week    Marketing    Net Wages  \
# count  324.000000   324.000000   324.000000   324.000000   324.000000
# mean   379.731481  2331.626543     3.027778  2707.561728   924.370370
# std    100.098398   263.108836     2.005218   333.751422   193.755739
# min    205.000000   754.000000     0.000000     0.000000     0.000000
# 25%    292.750000  2228.750000     1.000000  2750.000000   954.000000
# 50%    385.500000  2398.000000     3.000000  2750.000000   964.000000
# 75%    466.250000  2482.000000     5.000000  2750.000000  1024.000000
# max    547.000000  2686.000000     6.000000  2750.000000  1050.000000
#
#              Profit  Net Expenses
# count    324.000000    324.000000
# mean   23991.901235   3631.932099
# std     3013.056165    378.967125
# min     5224.000000    954.000000
# 25%    22659.250000   3612.000000
# 50%    24741.000000   3714.000000
# 75%    25819.500000   3774.000000
# max    28232.000000   3800.000000

# %%
plt.figure()
kalico_sales_data.plot()
# Out:
# <AxesSubplot:>

# %%
#Data Visualization:
df = kalico_sales_data
# Create a histogram of Sales, Marketing, Net Wages, and Profit
df[['Sales', 'Marketing', 'Net Wages', 'Profit']].hist(bins=20, figsize=(10, 8))
plt.show()

# Create a line plot of Sales, Marketing, Net Wages, and Profit over time
df.set_index('Day')[['Sales', 'Marketing', 'Net Wages', 'Profit']].plot(figsize=(10, 8))
plt.xlabel('Day')
plt.show()

# Create a bar plot of total Sales, Marketing, Net Wages, and Profit for each day of the week
df.groupby('Day of Week')[['Sales', 'Marketing', 'Net Wages', 'Profit']].sum().plot(kind='bar', figsize=(10, 8))
plt.show()

# Create a scatter plot of Sales and Profit
df.plot(kind='scatter', x='Sales', y='Profit', figsize=(10, 8))
plt.show()

# %%
#Correlation Analysis
df=df.drop(('Profit'),axis=1)
corr_matrix = df.corr()
corr_matrix
# Out:
#                    Day     Sales  Day of Week  Marketing  Net Wages  \
# Day           1.000000  0.473089    -0.015958   0.166073  -0.199137
# Sales         0.473089  1.000000     0.244011   0.372709   0.010747
# Day of Week  -0.015958  0.244011     1.000000   0.001767   0.171537
# Marketing     0.166073  0.372709     0.001767   1.000000  -0.041097
# Net Wages    -0.199137  0.010747     0.171537  -0.041097   1.000000
# Net Expenses  0.044445  0.333735     0.089258   0.859675   0.475079
#
#               Net Expenses
# Day               0.044445
# Sales             0.333735
# Day of Week       0.089258
# Marketing         0.859675
# Net Wages         0.475079
# Net Expenses      1.000000

# %%
'''
 Correlation coefficient of 0.5 or above is often considered to indicate a strong correlation, 
 while a coefficient between 0.3 and 0.5 is considered moderate. 
 Coefficients below 0.3 are generally considered weak or negligible. 
 We observe, Sales might correlate well with:
 Day (moderate correlation), Net Expenses (Moderate Correlation), Day of Week (low correlation)
'''
#Saving the Dataset
kalico_sales_data.to_csv(directory+'kalico_sales_final_set.csv',index=False)

# %%
df1 = pd.get_dummies(df, columns=['Day of Week'])
df1.corr()
# Out:
#                     Day     Sales  Marketing  Net Wages  Net Expenses  \
# Day            1.000000  0.473089   0.166073  -0.199137      0.044445
# Sales          0.473089  1.000000   0.372709   0.010747      0.333735
# Marketing      0.166073  0.372709   1.000000  -0.041097      0.859675
# Net Wages     -0.199137  0.010747  -0.041097   1.000000      0.475079
# Net Expenses   0.044445  0.333735   0.859675   0.475079      1.000000
# Day of Week_0  0.012153 -0.364280   0.051804  -0.159943     -0.036151
# Day of Week_1  0.017688  0.157456   0.051146   0.205813      0.150270
# Day of Week_2 -0.009436  0.026700  -0.094148  -0.356406     -0.265136
# Day of Week_3  0.006348 -0.097915  -0.022504   0.026911     -0.006060
# Day of Week_4 -0.022785  0.028506  -0.090286   0.074650     -0.041347
# Day of Week_5 -0.003716  0.130929   0.052458   0.148349      0.122046
# Day of Week_6  0.000405  0.116417   0.052458   0.059555      0.076648
#
#                Day of Week_0  Day of Week_1  Day of Week_2  Day of Week_3  \
# Day                 0.012153       0.017688      -0.009436       0.006348
# Sales              -0.364280       0.157456       0.026700      -0.097915
# Marketing           0.051804       0.051146      -0.094148      -0.022504
# Net Wages          -0.159943       0.205813      -0.356406       0.026911
# Net Expenses       -0.036151       0.150270      -0.265136      -0.006060
# Day of Week_0       1.000000      -0.163366      -0.165468      -0.163366
# Day of Week_1      -0.163366       1.000000      -0.163366      -0.161290
# Day of Week_2      -0.165468      -0.163366       1.000000      -0.163366
# Day of Week_3      -0.163366      -0.161290      -0.163366       1.000000
# Day of Week_4      -0.169638      -0.167483      -0.169638      -0.167483
# Day of Week_5      -0.167558      -0.165430      -0.167558      -0.165430
# Day of Week_6      -0.167558      -0.165430      -0.167558      -0.165430
#
#                Day of Week_4  Day of Week_5  Day of Week_6
# Day                -0.022785      -0.003716       0.000405
# Sales               0.028506       0.130929       0.116417
# Marketing          -0.090286       0.052458       0.052458
# Net Wages           0.074650       0.148349       0.059555
# Net Expenses       -0.041347       0.122046       0.076648
# Day of Week_0      -0.169638      -0.167558      -0.167558
# Day of Week_1      -0.167483      -0.165430      -0.165430
# Day of Week_2      -0.169638      -0.167558      -0.167558
# Day of Week_3      -0.167483      -0.165430      -0.165430
# Day of Week_4       1.000000      -0.171781      -0.171781
# Day of Week_5      -0.171781       1.000000      -0.169675
# Day of Week_6      -0.171781      -0.169675       1.000000

# %%
'''
The correlation matrix shows the pairwise correlations between Day, Sales, 
Marketing, Net Wages, Profit, Net Expenses, and the one-hot encoded days 
of the week (Day of Week_0, Day of Week_1, Day of Week_2, Day of Week_3, Day of Week_4, Day of Week_5, Day of Week_6).
The values on the diagonal are always 1.0, since the correlation of a variable with itself is always perfect.
The positive correlation between Day and Sales (0.473089) suggests that as the day increases, 
the sales also tend to increase.
The high correlation between Sales and Profit (0.992940) indicates that as sales increase, 
profits also tend to increase.
The positive correlation between Marketing and Net Expenses (0.859675) suggests that as 
marketing expenses increase, the net expenses also tend to increase.
The negative correlation between Net Wages and Profit (-0.048686) indicates that as 
net wages increase, the profit tends to decrease.
The one-hot encoded days of the week show a weak correlation with the other variables, 
suggesting that they may not have a strong influence on sales, marketing, net wages, profit, and net expenses.
'''
# Out:
# '\nThe correlation matrix shows the pairwise correlations between Day, Sales, \nMarketing, Net Wages, Profit, Net Expenses, and the one-hot encoded days \nof the week (Day of Week_0, Day of Week_1, Day of Week_2, Day of Week_3, Day of Week_4, Day of Week_5, Day of Week_6).\nThe values on the diagonal are always 1.0, since the correlation of a variable with itself is always perfect.\nThe positive correlation between Day and Sales (0.473089) suggests that as the day increases, \nthe sales also tend to increase.\nThe high correlation between Sales and Profit (0.992940) indicates that as sales increase, \nprofits also tend to increase.\nThe positive correlation between Marketing and Net Expenses (0.859675) suggests that as \nmarketing expenses increase, the net expenses also tend to increase.\nThe negative correlation between Net Wages and Profit (-0.048686) indicates that as \nnet wages increase, the profit tends to decrease.\nThe one-hot encoded days of the week show a weak correlation with the other variables, \nsuggesting that they may not have a strong influence on sales, marketing, net wages, profit, and net expenses.\n'

# %%
#Linear Regression Algorithm
from sklearn.linear_model import LinearRegression

#Linear Regression to predict sales based on day of Week, Net Wages and Marketing Costs
# Split the dataset into training and testing sets
train = df[:250]
test = df[250:]

# Select the features and target variable
X_train = train[['Day', 'Marketing']]
y_train = train['Sales']
X_test = test[['Day', 'Marketing']]
y_test = test['Sales']

# Train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the testing set
predictions = model.predict(X_test)

# Evaluate the model's performance
from sklearn.metrics import r2_score, mean_squared_error
r2 = r2_score(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
print("R^2 score:", r2)
print("MSE:", mse)

# Plot actual vs predicted sales
plt.plot(y_test.values)
plt.plot(predictions)
plt.legend(['Actual', 'Predicted'])
plt.show()
# Out:
# R^2 score: -0.8741610757028808
# MSE: 88287.89233820778

# %%
df
# Out:
#      Day  Sales  Day of Week  Marketing  Net Wages  Net Expenses
# 0    205    880            2        0.0     1026.0        1026.0
# 1    206    945            3        0.0      954.0         954.0
# 2    207   1289            4     2500.0      964.0        3464.0
# 3    207   1289            4      250.0      964.0        1214.0
# 4    208   1995            5     2750.0     1024.0        3774.0
# ..   ...    ...          ...        ...        ...           ...
# 319  543   2599            4     2750.0      964.0        3714.0
# 320  544   1331            5     2750.0      520.0        3270.0
# 321  545   2637            6     2750.0      968.0        3718.0
# 322  546   2070            0     2750.0      622.0        3372.0
# 323  547   2601            1     2750.0     1050.0        3800.0
#
# [324 rows x 6 columns]

# %%
#Decision Tree Algorithm
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Split your data into training and testing sets
#We drop profit from the data set.
X_train, X_test, y_train, y_test = train_test_split(df.drop(["Sales"], axis=1), df["Sales"], test_size=0.2)

# Initialize a decision tree regressor model
model = DecisionTreeRegressor()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model's performance
print("R^2 score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))

# Plot actual vs predicted sales
plt.plot(y_test.values)
plt.plot(y_pred)
plt.legend(['Actual', 'Predicted'])
plt.show()
# Out:
# R^2 score: 0.6297034444749328
# MSE: 32280.784615384615

# %%
'''
An R^2 score of 0.631 indicates that the model explains around 63.1% of the variance in the sales data, which is not bad. 
The MSE of 9938.04 suggests that the model's average sales predictions are off by around 99.68.
'''
# Out:
# "\nAn R^2 score of 0.631 indicates that the model explains around 63.1% of the variance in the sales data, which is not bad. \nThe MSE of 9938.04 suggests that the model's average sales predictions are off by around 99.68.\n"

# %%
#Random Forest

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop(["Sales"], axis=1), df["Sales"], test_size=0.2, random_state=42)

# Define the model
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model on the training data
rf.fit(X_train, y_train)

# Predict on the test data
y_pred = rf.predict(X_test)

# Print the R-squared score and MSE
print("R^2 score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))

# Plot actual vs predicted sales
plt.plot(y_test.values)
plt.plot(y_pred)
plt.legend(['Actual', 'Predicted'])
plt.show()
# Out:
# R^2 score: 0.7825276588179356
# MSE: 21498.47098153846

# %%
#Random Forest Model performs better than the Decision Tree Model as can be observed from the R^2 value of 0.78.
#The MSE value of 21498.47 means that the average error in predicting the sales value is likely to be 146.6

#LSTM Model

from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# Split into training and testing sets
train_size = int(len(df) * 0.7)
train_set = df.iloc[:train_size, 1:2].values
test_set = df.iloc[train_size:, 1:2].values

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
train_set_scaled = scaler.fit_transform(train_set)

# Create input and output sequences for the LSTM model
x_train = []
y_train = []
for i in range(60, len(train_set_scaled)):
    x_train.append(train_set_scaled[i-60:i, 0])
    y_train.append(train_set_scaled[i, 0])
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the input data for LSTM model
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the LSTM model
model.fit(x_train, y_train, epochs=100, batch_size=32)

# Prepare the test data
inputs = df.iloc[len(df) - len(test_set) - 60:, 1:2].values
inputs = scaler.transform(inputs)
x_test = []
for i in range(60, len(inputs)):
    x_test.append(inputs[i-60:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Predict the sales
predicted_sales = scaler.inverse_transform(model.predict(x_test))

# Calculate the R^2 score and MSE
mse = mean_squared_error(test_set, predicted_sales)
r2 = r2_score(test_set, predicted_sales)

print(f"R^2 score: {r2}")
print(f"MSE: {mse}")

# Plot actual vs predicted sales
plt.plot(test_set)
plt.plot(predicted_sales)
plt.legend(['Actual', 'Predicted'])
plt.show()
# Out:
# Epoch 1/100
# 6/6 [==============================] - 3s 33ms/step - loss: 0.4404
# Epoch 2/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0435
# Epoch 3/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0200
# Epoch 4/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0214
# Epoch 5/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0112
# Epoch 6/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0070
# Epoch 7/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0068
# Epoch 8/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0055
# Epoch 9/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0056
# Epoch 10/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0051
# Epoch 11/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0051
# Epoch 12/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 13/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 14/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 15/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0051
# Epoch 16/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 17/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 18/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0051
# Epoch 19/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 20/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 21/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 22/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0052
# Epoch 23/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0051
# Epoch 24/100
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0051
# Epoch 25/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 26/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0051
# Epoch 27/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0053
# Epoch 28/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0053
# Epoch 29/100
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0051
# Epoch 30/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0054
# Epoch 31/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0054
# Epoch 32/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 33/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0052
# Epoch 34/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 35/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 36/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 37/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0050
# Epoch 38/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0052
# Epoch 39/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 40/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0058
# Epoch 41/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0054
# Epoch 42/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 43/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0056
# Epoch 44/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 45/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0050
# Epoch 46/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 47/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 48/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 49/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 50/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0053
# Epoch 51/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0050
# Epoch 52/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0053
# Epoch 53/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0051
# Epoch 54/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0052
# Epoch 55/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0057
# Epoch 56/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0061
# Epoch 57/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0050
# Epoch 58/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0058
# Epoch 59/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0052
# Epoch 60/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0051
# Epoch 61/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0053
# Epoch 62/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0054
# Epoch 63/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0054
# Epoch 64/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0050
# Epoch 65/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0053
# Epoch 66/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 67/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0051
# Epoch 68/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 69/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0052
# Epoch 70/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0050
# Epoch 71/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0052
# Epoch 72/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0050
# Epoch 73/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0051
# Epoch 74/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0052
# Epoch 75/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0051
# Epoch 76/100
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0053
# Epoch 77/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0052
# Epoch 78/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0053
# Epoch 79/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0050
# Epoch 80/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0051
# Epoch 81/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0053
# Epoch 82/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0052
# Epoch 83/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0054
# Epoch 84/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0052
# Epoch 85/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0054
# Epoch 86/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0051
# Epoch 87/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0051
# Epoch 88/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0051
# Epoch 89/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0058
# Epoch 90/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0058
# Epoch 91/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0057
# Epoch 92/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0053
# Epoch 93/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0050
# Epoch 94/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0054
# Epoch 95/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0054
# Epoch 96/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0051
# Epoch 97/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0051
# Epoch 98/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0050
# Epoch 99/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0050
# Epoch 100/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0052
# 4/4 [==============================] - 1s 14ms/step
# R^2 score: -0.03739016610158563
# MSE: 44414.479619184924

# %%
#Let's try increasing the previous sales data points used and see how the model performs.

#LSTM2

train_size = int(len(df) * 0.7)
train_set = df.iloc[:train_size, 1:2].values
test_set = df.iloc[train_size:, 1:2].values


scaler = MinMaxScaler(feature_range=(0, 1))
train_set_scaled = scaler.fit_transform(train_set)


x_train = []
y_train = []
for i in range(100, len(train_set_scaled)):
    x_train.append(train_set_scaled[i-100:i, 0])
    y_train.append(train_set_scaled[i, 0])
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the input data for LSTM model
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# Build the LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the LSTM model
model.fit(x_train, y_train, epochs=100, batch_size=32)

# Prepare the test data
inputs = df.iloc[len(df) - len(test_set) - 100:, 1:2].values
inputs = scaler.transform(inputs)
x_test = []
for i in range(100, len(inputs)):
    x_test.append(inputs[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Predict the sales
predicted_sales = scaler.inverse_transform(model.predict(x_test))

# Calculate the R^2 score and MSE
mse = mean_squared_error(test_set, predicted_sales)
r2 = r2_score(test_set, predicted_sales)

print(f"R^2 score: {r2}")
print(f"MSE: {mse}")

# Plot actual vs predicted sales
plt.plot(test_set)
plt.plot(predicted_sales)
plt.legend(['Actual', 'Predicted'])
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 59ms/step - loss: 0.4194
# Epoch 2/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0511
# Epoch 3/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0700
# Epoch 4/100
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0106
# Epoch 5/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0263
# Epoch 6/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0188
# Epoch 7/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0073
# Epoch 8/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0108
# Epoch 9/100
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0088
# Epoch 10/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0059
# Epoch 11/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0074
# Epoch 12/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0067
# Epoch 13/100
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0061
# Epoch 14/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0064
# Epoch 15/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0060
# Epoch 16/100
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0060
# Epoch 17/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0061
# Epoch 18/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0060
# Epoch 19/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0059
# Epoch 20/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0060
# Epoch 21/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0059
# Epoch 22/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0060
# Epoch 23/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0060
# Epoch 24/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 25/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0059
# Epoch 26/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0059
# Epoch 27/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 28/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 29/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0059
# Epoch 30/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 31/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 32/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0059
# Epoch 33/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0059
# Epoch 34/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0059
# Epoch 35/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0059
# Epoch 36/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 37/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0059
# Epoch 38/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0059
# Epoch 39/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0059
# Epoch 40/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0059
# Epoch 41/100
# 4/4 [==============================] - 0s 80ms/step - loss: 0.0059
# Epoch 42/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0059
# Epoch 43/100
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0059
# Epoch 44/100
# 4/4 [==============================] - 0s 77ms/step - loss: 0.0059
# Epoch 45/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0059
# Epoch 46/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 47/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0059
# Epoch 48/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0059
# Epoch 49/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0059
# Epoch 50/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 51/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 52/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0059
# Epoch 53/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 54/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 55/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0060
# Epoch 56/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0059
# Epoch 57/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 58/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0059
# Epoch 59/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0061
# Epoch 60/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0059
# Epoch 61/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0061
# Epoch 62/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 63/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0059
# Epoch 64/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0060
# Epoch 65/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0059
# Epoch 66/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0060
# Epoch 67/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 68/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 69/100
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0059
# Epoch 70/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0058
# Epoch 71/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0059
# Epoch 72/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0060
# Epoch 73/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0059
# Epoch 74/100
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0059
# Epoch 75/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0060
# Epoch 76/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 77/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 78/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0058
# Epoch 79/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0058
# Epoch 80/100
# 4/4 [==============================] - 0s 74ms/step - loss: 0.0059
# Epoch 81/100
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0058
# Epoch 82/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 83/100
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0059
# Epoch 84/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0058
# Epoch 85/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0058
# Epoch 86/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0059
# Epoch 87/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0058
# Epoch 88/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0060
# Epoch 89/100
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0058
# Epoch 90/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0058
# Epoch 91/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0058
# Epoch 92/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0058
# Epoch 93/100
# 4/4 [==============================] - 0s 70ms/step - loss: 0.0059
# Epoch 94/100
# 4/4 [==============================] - 0s 71ms/step - loss: 0.0058
# Epoch 95/100
# 4/4 [==============================] - 0s 78ms/step - loss: 0.0060
# Epoch 96/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0058
# Epoch 97/100
# 4/4 [==============================] - 0s 69ms/step - loss: 0.0060
# Epoch 98/100
# 4/4 [==============================] - 0s 75ms/step - loss: 0.0059
# Epoch 99/100
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0058
# Epoch 100/100
# 4/4 [==============================] - 0s 72ms/step - loss: 0.0059
# 4/4 [==============================] - 1s 18ms/step
# R^2 score: -0.039170836622534955
# MSE: 44490.716658194455

# %%
'''
It seems that increasing the number of input data points from 60 to 100 did not improve the model's performance. 
The R^2 score and MSE values are still not good, indicating that the model is not able to accurately predict sales 
based on the given features. We should consider revising the model architecture or trying a different approach 
to improve the results.
'''

df
# Out:
#      Day  Sales  Day of Week  Marketing  Net Wages  Net Expenses
# 0    205    880            2        0.0     1026.0        1026.0
# 1    206    945            3        0.0      954.0         954.0
# 2    207   1289            4     2500.0      964.0        3464.0
# 3    207   1289            4      250.0      964.0        1214.0
# 4    208   1995            5     2750.0     1024.0        3774.0
# ..   ...    ...          ...        ...        ...           ...
# 319  543   2599            4     2750.0      964.0        3714.0
# 320  544   1331            5     2750.0      520.0        3270.0
# 321  545   2637            6     2750.0      968.0        3718.0
# 322  546   2070            0     2750.0      622.0        3372.0
# 323  547   2601            1     2750.0     1050.0        3800.0
#
# [324 rows x 6 columns]

# %%
#ARIMA Model

from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

df = kalico_sales_data.drop('Profit',axis=1)
#Arima requires continuous data, therefore we are forced to delete data for days before when break in frequency has occured.
df=df[df['Day']>=373]  #Obtained from day_break function above.
#function to return a date when a day number is inserted. This function assumes the year to start from 2021.
def return_date(day):
    # Convert day number to datetime
    date = pd.Timestamp('2021-01-01') + pd.Timedelta(days=day-1)
    return date

# Add the year to the datetime objects
#Converting the Day column to a datetime object
df['Day'] = df['Day'].apply(lambda x: return_date(x))

df
# Out:
#            Day  Sales  Day of Week  Marketing  Net Wages  Net Expenses
# 149 2022-01-08   2396            2        0.0     1026.0        1026.0
# 150 2022-01-09   2332            3     2750.0      954.0        3704.0
# 151 2022-01-10   2391            4     2750.0      964.0        3714.0
# 152 2022-01-11   2461            5     2750.0     1024.0        3774.0
# 153 2022-01-12   2460            6     2750.0      968.0        3718.0
# ..         ...    ...          ...        ...        ...           ...
# 319 2022-06-27   2599            4     2750.0      964.0        3714.0
# 320 2022-06-28   1331            5     2750.0      520.0        3270.0
# 321 2022-06-29   2637            6     2750.0      968.0        3718.0
# 322 2022-06-30   2070            0     2750.0      622.0        3372.0
# 323 2022-07-01   2601            1     2750.0     1050.0        3800.0
#
# [175 rows x 6 columns]

# %%
#Step 1: Plot the time series data to see if there is any seasonality, irregularity or trend in the data.
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 6))

# Plot the time series
plt.plot(df['Day'], df['Sales'])

# Set the x-axis label
plt.xlabel('Date')

# Set the y-axis label
plt.ylabel('Sales')

# Show the plot
plt.show()

# %%
#Step 2: Perform tests to understand if the time series is stationary:
# Perform Augmented Dickey-Fuller test

from statsmodels.tsa.stattools import adfuller

result = adfuller(df["Sales"])
print("ADF statistic:", result[0])
print("p-value:", result[1])
for key, value in result[4].items():
    print("Critical value %s: %.3f" % (key, value))
# Out:
# ADF statistic: -4.121082291096019
# p-value: 0.0008936629945633685
# Critical value 1%: -3.472
# Critical value 5%: -2.880
# Critical value 10%: -2.576

# %%
''' 
The ADF statistic is more negative than the critical values at the 1%, 5%, and 10% levels, 
which means we can reject the null hypothesis and conclude that the time series is stationary 
with a high level of confidence. The p-value is also less than 0.05, which further supports the 
conclusion that the time series is stationary.
'''

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# create ACF and PACF plots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10,8))
plot_acf(df['Sales'].dropna(), lags=25, ax=ax1)
plot_pacf(df['Sales'].dropna(), lags=25, ax=ax2)
plt.show()
# Out:
# C:\Users\shine\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
'''
Based on the ACF and PACF plots above, we see that at lag 21, the ACF has a significant correlation and 
PACF drops off sharply. This means that there is a seasonality in the data of about 21 days and we will
be using the SARIMA model. The SARIMA model combines the ARIMA model with a seasonal component that models
the periodic behavior of the time series. We specify the seasonal component of the SARIMA model using the 
notation SARIMA(p,d,q)(P,D,Q)m, where (p,d,q) are the non-seasonal ARIMA parameters, (P,D,Q) are the seasonal 
ARIMA parameters, and m is the number of periods in a season.
'''
# Out:
# '\nBased on the ACF and PACF plots above, we see that at lag 21, the ACF has a significant correlation and \nPACF drops off sharply. This means that there is a seasonality in the data of about 21 days and we will\nbe using the SARIMA model. The SARIMA model combines the ARIMA model with a seasonal component that models\nthe periodic behavior of the time series. We specify the seasonal component of the SARIMA model using the \nnotation SARIMA(p,d,q)(P,D,Q)m, where (p,d,q) are the non-seasonal ARIMA parameters, (P,D,Q) are the seasonal \nARIMA parameters, and m is the number of periods in a season.\n'

# %%
#SARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt

# Perform train-test split
train_data = df['Sales'][:-30]
test_data = df['Sales'][-30:]

# Define the SARIMA model
order = (0, 0, 1)
seasonal_order = (0, 1, 1, 21)
model = SARIMAX(train_data, order=order, seasonal_order=seasonal_order)

# Fit the model
model_fit = model.fit()

# Make predictions for the test data
forecast = model_fit.forecast(steps=len(test_data))

# Compute R-squared and RMSE values
r2 = r2_score(test_data, forecast)
rmse = np.sqrt(mean_squared_error(test_data, forecast))

# Print the R-squared and RMSE values
print('R-squared:', r2)
print('RMSE:', rmse)

# Plot the predicted vs actual sales values
plt.figure(figsize=(12,6))
plt.plot(test_data.index, test_data.values, label='Actual Sales')
plt.plot(test_data.index, forecast.values, label='Predicted Sales')
plt.legend()
plt.xlabel('Day')
plt.ylabel('Sales')
plt.title('Actual vs Predicted Sales')
plt.show()
# Out:
# C:\Users\shine\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\shine\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\shine\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# R-squared: 0.2599930226305448
# RMSE: 234.64424177073815

# %%
df.set_index("Day", inplace=True)
df.index.freq='D'

# Create a new column for the sales differences
df["SalesDiff"] = df["Sales"].diff()

# Drop the first row (which has a NaN value)
df.dropna(inplace=True)

# Split the data into training and testing sets
train_data = df[:121]
test_data = df[121:]

# Fit an ARIMA model on the training data
model = ARIMA(train_data["SalesDiff"], order=(1, 1, 1))
model_fit = model.fit()

# Compute the predicted values for the test data
predictions = model_fit.forecast(steps=len(test_data), freq='D').iloc[0:-1]


# Compute the actual values for the test data
actual_values = test_data["SalesDiff"]

# Remove the last value from the actual_values
actual_values = actual_values[:-1]


# Compute the root mean squared error (RMSE)
rmse = mean_squared_error(actual_values, predictions, squared=False)

# Print the RMSE
print("RMSE:", rmse)

# Add a new column to the df DataFrame that contains the predicted sales for the test data
df["PredictedSales"] = train_data["Sales"].iloc[-1] + predictions.cumsum()

# Create a line plot that shows the actual and predicted sales over time
df[["Sales", "PredictedSales"]].plot(figsize=(10, 5))
plt.title("Actual vs Predicted Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()
